# %%
f = open('//dev//frog_song.txt', 'w')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 f = open('//dev//frog_song.txt', 'w')
#
# File ~/PythonBasic/python_venv/lib/python3.14/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 1] Operation not permitted: '//dev//frog_song.txt'

# %%
import os

os.makedirs('/Users/gimdabin/PythonBasic/python_basic/17_file-io/dev', exist_ok=True)

# %%
f = open('dev/frog_song.txt', 'w')

# %%
f = open('dev/frog_song.txt', 'r', encoding="utf-8")

# %%
f.write('개구리 소년 빰빠바 개구리 소년 빰빠바\n\n네가 울면 무지개 연못에 비가 온단다\n비바람 몰아쳐도 이겨내고\n일곱번 넘어져도 일어나~라\n울지말고 일어나 피리를 불어라\n\n삘릴리 개굴개굴 삘릴리리\n삘릴리 개굴개굴 삘릴리리\n\n무지개 연못에 웃음꽃 핀다.\n')
f.close()

# %%
f = open('./dev/frog_song.txt', 'r')
# /Users/gimdabin/PythonBasic/python_basic/17_file-io/dev/frog_song.txt

data = f.read()
print(data)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('dev/frog_song.txt', 'w')
data = ['개구리 소년 빰빠바 개구리 소년 빰빠바\n\n', '네가 울면 무지개 연못에 비가 온단다\n', '비바람 몰아쳐도 이겨내고\n', '일곱번 넘어져도 일어나~라\n', '울지말고 일어나 피리를 불어라\n\n', '삘릴리 개굴개굴 삘릴리리\n', '삘릴리 개굴개굴 삘릴리리\n\n', '무지개 연못에 웃음꽃 핀다.\n']
f.writelines(data)

# %%
f = open('./dev/frog_song.txt', 'r')

line = f.readline()

print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바

# %%
f = open('./dev/frog_song.txt', 'r')

while True:
    line = f.readline()

    if not line:
        break
    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('./dev/frog_song.txt', 'r')

line = f.readlines()
print(line)

f.close()
# Out:
# ['개구리 소년 빰빠바 개구리 소년 빰빠바\n', '\n', '네가 울면 무지개 연못에 비가 온단다\n', '비바람 몰아쳐도 이겨내고\n', '일곱번 넘어져도 일어나~라\n', '울지말고 일어나 피리를 불어라\n', '\n', '삘릴리 개굴개굴 삘릴리리\n', '삘릴리 개굴개굴 삘릴리리\n', '\n', '무지개 연못에 웃음꽃 핀다.\n']

# %%
f = open('./dev/frog_song.txt', 'r')

lines = f.readlines()

for line in lines:
    if line == '\n':
        continue

    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('./dev/frog_song.txt', 'r')

for line in f:
    if line == '\n':
        continue
    
    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f1 = open('./dev/frog_song.txt', 'a')
f1.write("노래 끝~")

f1.close()

f2 = open('./dev/frog_song.txt', 'r')
print(f2.read())

f2.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.
# 노래 끝~노래 끝~

# %%
f1 = open('./dev/frog_song.txt', 'a')
f1.write("10")

f1.close()

# %%
#절대경로
# with open("/Users/gimdabin/PythonBasic/python_basic/17_file-io/new/fi/le/newFile2.txt", 'w') as f:
#     f.write("Life is too short, you need Python")

#상대경로
with open("./new/fi/le/newFile2.txt", 'w') as f:
    f.write("Life is too short, you need Python")
