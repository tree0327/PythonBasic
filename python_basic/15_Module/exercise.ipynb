# %%
import ohgiraffers_module

print(ohgiraffers_module.ohgiraffers)
print(ohgiraffers_module.gorilla())
print(ohgiraffers_module.tiger())
print(ohgiraffers_module.pig())
# Out:
# 국내최고 IT 교육 전문 강사진
# 캉
# 흥
# 꿀

# %%
from ohgiraffers_module import ohgiraffers, gorilla

print(ohgiraffers)
print(gorilla())
# Out:
# 국내최고 IT 교육 전문 강사진
# 캉

# %%
import ohgiraffers_module as OGModule

print(OGModule.ohgiraffers)
print(OGModule.gorilla())
# Out:
# 국내최고 IT 교육 전문 강사진
# 캉

# %%
from ohgiraffers_module import ohgiraffers as oh, gorilla as gor
print(oh)
print(gor())
# Out:
# 국내최고 IT 교육 전문 강사진
# 캉

# %%
import math

print(math.sqrt(16))
print(math.factorial(5))
print(math.pi)
# Out:
# 4.0
# 120
# 3.141592653589793

# %%
# import sys
# import os

# sys.path.append(os.path.dirname(os.path.dirname(__file__)))
# import ohgiraffers_module
