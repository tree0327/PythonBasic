# %%
print("""
세상에서 제일 긴 게 뭘까요?
기차? 기린의 목? 코끼리의 코?
전부 아닙니다.
여러분의 무한한 가능성입니다^^
""")
# Out:
# 세상에서 제일 긴 게 뭘까요?
# 기차? 기린의 목? 코끼리의 코?
# 전부 아닙니다.
# 여러분의 무한한 가능성입니다^^

# %%
"""
여러줄 주석을 쓸 때에도 사용
개발에 대한 주석
"""
# Out:
# '\n여러줄 주석을 쓸 때에도 사용\n개발에 대한 주석\n'

# %%
greeting = "반갑습니"
name = "다람쥐"
print(greeting + name)
print(greeting + "다. " + name + "입니다.")
# Out:
# 반갑습니다람쥐
# 반갑습니다. 다람쥐입니다.

# %%
name = "카피바라"
print(str(900) + "살 " + name + "입니다.")
# Out:
# 900살 카피바라입니다.

# %%
subject = "python"
print("무슨 일이든 시작 전에 세 번만 외쳐보자!" + (" 나는 " + subject + "을 잘할 수 있다.") * 3)
# Out:
# 무슨 일이든 시작 전에 세 번만 외쳐보자! 나는 python을 잘할 수 있다. 나는 python을 잘할 수 있다. 나는 python을 잘할 수 있다.

# %%
enrole_date = '2024/12/16'
rep_enrole_date = enrole_date.replace("/", "-")

print(rep_enrole_date)
# Out:
# 2024-12-16

# %%
origin = 'ohgiraffers'
with_white_space = '        oh giraffers        '

print(with_white_space.strip())
# Out:
# oh giraffers

# %%
print(with_white_space.strip('        o'))
# Out:
# h giraffers

# %%
print(origin.strip('os'))
# Out:
# hgiraffer

# %%
print(origin.lstrip("os"))
print(origin.rstrip("os"))
# Out:
# hgiraffers
# ohgiraffer

# %%
origin_str  ='hELLO wORLD!'

print(origin_str.upper())
print(origin_str.lower())
print(origin_str.capitalize())
print(origin_str.swapcase())
print(origin_str.title())
# Out:
# HELLO WORLD!
# hello world!
# Hello world!
# Hello World!
# Hello World!

# %%
x = 10
print("x is %d" %x)

y = "code"
print("y is %s" %y)
# Out:
# x is 10
# y is code

# %%
x, y = 10, "code"

print("x is {0}".format(x))
print("x is {0} y is {1}".format(x, y))
print("x is {new_x} and y is {new_y}".format(new_x=x, new_y=y))
# Out:
# x is 10
# x is 10 y is code
# x is 10 and y is code

# %%
teacher_name = "카피바라"

print(f"안녕하세요. 오늘부터 여러분과 함꼐 공부할 {teacher_name} 강사 입니다.")
# Out:
# 안녕하세요. 오늘부터 여러분과 함꼐 공부할 카피바라 강사 입니다.

# %%
print(True + 3)
print(3 + 5.0)
print(type(True + 3))
print(type(5.0 + 3))
# Out:
# 4
# 8.0
# <class 'int'>
# <class 'float'>

# %%
# print(3 + "5")
print(type(3))
print(type("5"))
# Out:
# <class 'int'>
# <class 'str'>

# %%
print(int('3') + 4)
# Out:
# 7

# %%
print(float('3') + 4)
# Out:
# 7.0

# %%
print(str(1))
print(str(1.0))
print(str({1, 2, 3}))
# Out:
# 1
# 1.0
# {1, 2, 3}

# %%
print(list('ohgiraffers'))
# Out:
# ['o', 'h', 'g', 'i', 'r', 'a', 'f', 'f', 'e', 'r', 's']

# %%
print(list((1, 2, 3, 4, 5)))
# Out:
# [1, 2, 3, 4, 5]

# %%
#dictionary를 list화하면 value는 사라지고 key값만 리스트화 된다.

print(list({
    "1": "사랑하는 우리반",
    "2": "열심히 공부하십시오.",
    "3": "선생님 부탁입니다."
}))
# Out:
# ['1', '2', '3']
